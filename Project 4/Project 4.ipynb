# %% [markdown]
# ## Project #4 - DO NOT READ
#
# ![image.png](attachment:image.png)
#
#
#     This is a big one so do not wait.
#     The goal of this project is to understand working with others code and the boundries that have been set for you.
#
# I know you are going to hate me so lets rip the bandade off.
# Pick one of the group projects you reviewed and fork it. Please check with the developer of the project first to ensure they finished there reviews and importing all the comments.
# You may use every resorcse avalable to you. (yes even chat gpt)
# You will now do the unspeakable. You will compleatly redesign there program.
# You must uses every topic we have talked about for this project.
# - This includes docker, Multicore or treading (not asynco)

# %% [markdown]
# have a juypiter notbook with code snipits of all the sections...
